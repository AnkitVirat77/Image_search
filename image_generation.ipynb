# %%
import google.generativeai as genai
from dotenv import load_dotenv
import os

# %%
load_dotenv()
# Out:
# True

# %%
gemini_api_key = os.getenv('gemini_api_key')
genai.configure(api_key = gemini_api_key)

# %%
model = genai.GenerativeModel("gemini-2.0-flash")
model
# Out:
# genai.GenerativeModel(
#     model_name='models/gemini-2.0-flash',
#     generation_config={},
#     safety_settings={},
#     tools=None,
#     system_instruction=None,
#     cached_content=None
# )

# %% [markdown]
# - so here we are sending a promt and image
#
# - we will read image using
#    - pillow package

# %%
from PIL import Image

# %%
img = Image.open('img.png')
img
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=512x512>

# %%
promt = "Describe the color of eye"

# %%
Input = [promt,img]
response = model.generate_content(Input)
print(response.text)
# Out:
# The parrot's eye appears to be light blue.

# %% [markdown]
# - We import required packages
#
# - We loaded env file
#
# - We load the Gemini key
#
# - We load the geminu model
#
# - We load the image
#
# - We define the promt
#
# - We are asking to the model generate the answer by taking image and promt

# %%
import google.generativeai as genai
from dotenv import load_dotenv
import os
from PIL import Image
import streamlit as st

load_dotenv()

gemini_api_key = os.getenv('gemini_api_key')
genai.configure(api_key = gemini_api_key)

st.header("Image analytics")
uploaded_file = st.file_uploader("Upload an image", type=["png","jpg","jpeg"])
if uploaded_file is not None:
    st.image(Image.open(uploaded_file))

promt = st.text_input("Enter the text")

if st.button("GET RESPONSE"):
    img = Image.open(uploaded_file)
    model = genai.GenerativeModel("gemini-2.0-flash")
    response=model.generate_content([promt,img])
    st.markdown(response.text)


model = genai.GenerativeModel("gemini-2.0-flash")
image = st.upload_file()
model



img = Image.open('img.png')
img

promt = "Describe the image"

Input = [promt,img]
response = model.generate_content(Input)
print(response.text)
